# %%
""" 
Notebook to work with loaded data. 
The package save automatically the output of the inference in pickle files. 
When you want to just analyze data, you can use the following commands.
"""

# %%
from test_beta_package import *
# %matplotlib inline

# %%
# first you check that the structure of folders is valid and you save them in the memory #

path_data_folder, path_raw_data_folder, path_process_data_folder, path_top_folder, path_info_dir, path_analysis_dir, \
path_plots_dir, path_single_pred_dir, path_multi_pred_dir = folder_structure()

# %%
# %%capture cap --no-stderr 
# Command above to avoid printing all the posterior probabilities
# Below you process the posterior probability and states occupancies # #if you haven't computed before#
posterior_probs_list = posterior_prob_process(path_info_dir, path_analysis_dir, dict_processed_objects=0)
states_occupancies = states_occupancies_computation(path_analysis_dir, posterior_probs_list=None, dict_posterior=0)

# %%
# Below plotting the quantities you are interested in #

# %%
log_like_evolution_per_states(path_analysis_dir, path_info_dir, dict_objects=0, dict_processed_objects=0)
# Out:
# 2 8

# %%
colors_number(colors_number=3)
# Out:
# array([[0.        , 0.        , 0.5       , 1.        ],
#        [0.49019608, 1.        , 0.47754586, 1.        ],
#        [0.5       , 0.        , 0.        , 1.        ]])

# %%
states_occupancies_histogram(path_analysis_dir, path_info_dir, dict_param=0, file_states_occup=0)
# Out:
# state of occupancy is [0.00317235 0.29900727 0.69782038]
# colors number is 3

# %%
transition_prob_matrix(path_analysis_dir, path_info_dir, dict_param=0, dict_processed_objects=0)

# %%
weights_distribution_histogram(path_analysis_dir, path_info_dir)
# Out:
# inferred and transformed weights are {'2_states': [array([[[0.50077836, 0.97900423]],
#
#        [[0.49794706, 0.9986581 ]]]), array([[[0.50632827, 0.99173082]],
#
#        [[0.51291816, 0.98973326]]]), array([[[0.49999193, 0.98134012]],
#
#        [[0.49981732, 0.99963235]]]), array([[[0.49715688, 0.99795006]],
#
#        [[0.50025323, 0.98074481]]]), array([[[0.49701849, 0.99847191]],
#
#        [[0.50020409, 0.98071899]]]), array([[[0.49949166, 0.99848133]],
#
#        [[0.50006779, 0.98068403]]]), array([[[0.49792515, 0.9940221 ]],
#
#        [[0.50061693, 0.99310953]]]), array([[[0.50022022, 0.98065178]],
#
#        [[0.50064448, 0.99847827]]])], '3_states': [array([[[0.50136151, 0.96023362]],
#
#        [[0.50768164, 0.9946948 ]]]), array([[[0.49323646, 0.97442495]],
#
#        [[0.46535358, 0.99918978]]]), array([[[0.50615395, 0.99759191]],
#
#        [[0.50194481, 0.97134911]]]), array([[[0.50678673, 0.9983254 ]],
#
#        [[0.50052931, 0.96933847]]]), array([[[0.51044081, 0.99785635]],
#
#        [[0.49787262, 0.97244399]]]), array([[[0.50044557, 0.97614006]],
#
#        [[0.49994058, 0.99967233]]]), array([[[0.49965423, 0.97151594]],
#
#        [[0.50075738, 0.99730911]]]), array([[[0.50065254, 0.99987774]],
#
#        [[0.50004101, 0.97529728]]])]}
# 50 50
# 50 50
# 50 50
